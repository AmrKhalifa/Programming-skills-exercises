# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def cos_decay(step, t_steps, max_lr, min_lr =0):
    lr = min_lr + (max_lr-min_lr)*(1+math.cos(math.pi*step/t_steps))/ 2
    return lr

# %%
def linear_warmup_cos_decay():
    pass

# %%
def cyclical_cos_decay():
    pass

# %%
def decayed_cyclical_cos_decay():
    pass

# %%
max_lr = 1e-3
min_lr = 0
steps = [50, 100]

solutions = []

for step in steps:
    sol = []
    for i in range(step):
        sol.append(cos_decay(i, step, max_lr, min_lr))
    solutions.append(sol)

# %%
plt.plot(solutions[0],)
plt.plot(solutions[1])

# %%
max_lr = 1e-3
min_lr = [0, 1e-4]

solutions = []

for mlr in min_lr:
    sol = []
    for i in range(100):
        sol.append(cos_decay(i, 100, max_lr, mlr))
    solutions.append(sol)

# %%
plt.plot(solutions[0],)
plt.plot(solutions[1])
